# %% [markdown]
# # 01 — EDA y consolidación de datos
#
# **Objetivo:** entender la calidad/cobertura de las fuentes en `data/raw/` y producir `data/processed/matches_master.parquet`.
#
# Ver `docs/PLAN.md` Fase 1 para el checklist completo.

# %%
import sys; sys.path.append('..')
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path
from src.data_loader import load_results, load_fifa_ranking

DATA_RAW = Path('../data/raw')
FIG = Path('../figures'); FIG.mkdir(exist_ok=True)

# %% [markdown]
# ## 1. Cargar results.csv

# %%
res = load_results()
print(res.shape)
res.head()

# %% [markdown]
# ## 2. Distribución temporal

# %%
res['year'] = res['date'].dt.year
fig, ax = plt.subplots(figsize=(12,4))
res.groupby('year').size().plot(ax=ax)
ax.set_title('Partidos internacionales por año')
plt.savefig(FIG/'01_partidos_por_anio.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Tipos de torneo

# %%
res['tournament'].value_counts().head(15)

# %% [markdown]
# ## 4. FIFA ranking

# %%
rank = load_fifa_ranking()
print(rank.shape)
rank.head()

# %% [markdown]
# ## 5. Parsear grupos 2026
#
# Desde `data/raw/openfootball-worldcup/2026--usa/cup.txt` extraer los 12 grupos y guardar `data/processed/groups_2026.csv`. Implementar en `src/data_loader.py`.
#
# **Validación:** los 48 equipos deben aparecer exactamente una vez.

# %% [markdown]
# ## 6. Tarea siguiente
#
# Una vez todas las celdas corran sin error → generar `matches_master.parquet`.
